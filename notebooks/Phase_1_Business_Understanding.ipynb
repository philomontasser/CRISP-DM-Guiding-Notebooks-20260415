# %% [markdown]
# # Phase 1: Business Understanding
#
# **CRISP-DM Phase Description:**
# This phase focuses on understanding the project objectives and requirements from a business perspective, then converting this knowledge into a data mining problem definition and a preliminary plan designed to achieve the objectives.
#
# ---

# %% [markdown]
# ### Task 1: Determine Business Objectives
#
# The first objective of the data analyst is to thoroughly understand, from a business perspective, what the customer really wants to accomplish. This involves:
#
# - **Background:** Identify the organisational context and the business area the project relates to.
# - **Business Objectives:** Clearly state the primary question or problem the business wants to solve.
# - **Business Success Criteria:** Define the measurable criteria that determine whether the project's outcome is considered a success from the business's point of view (e.g., "reduce customer churn by 15%", "improve prediction accuracy to 90%").
#
# **Instructions:** In the cells below, define your business objectives, background context, and success criteria as Python variables (strings or dictionaries). This ensures your business logic is documented directly in the notebook's code state.

# %%
business_objectives = {
    "project_name": "HR Employee Attrition Risk Assessment",
    "background": (
        "The HR team wants to understand which employees are most likely to leave "
        "so retention actions can be targeted before attrition happens."
    ),
    "primary_objective": (
        "Predict whether an employee is likely to leave the company and identify "
        "the strongest drivers of attrition."
    ),
    "stakeholders": [
        "HR business partners",
        "People analytics team",
        "Department managers",
        "Executive leadership",
    ],
    "business_success_criteria": [
        "Produce a ranked attrition-risk view that HR can use for intervention planning.",
        "Reach recall of at least 0.60 on attrition cases so a majority of leavers are flagged.",
        "Maintain precision near or above 0.40 to avoid overwhelming HR with false positives.",
        "Surface actionable drivers such as overtime, travel burden, tenure, and job satisfaction.",
    ],
    "expected_benefits": [
        "Lower replacement and onboarding costs",
        "Better workforce planning",
        "More targeted retention programmes",
        "Improved employee experience for at-risk groups",
    ],
}

# %%
# Display the defined objectives in a readable format
for key, value in business_objectives.items():
    print(f">> {key.upper().replace('_', ' ')}:")
    if isinstance(value, list):
        for item in value:
            print(f"   - {item}")
    else:
        print(f"   {value}")
    print()
# Out:
# >> PROJECT NAME:
#    HR Employee Attrition Risk Assessment
#
# >> BACKGROUND:
#    The HR team wants to understand which employees are most likely to leave so retention actions can be targeted before attrition happens.
#
# >> PRIMARY OBJECTIVE:
#    Predict whether an employee is likely to leave the company and identify the strongest drivers of attrition.
#
# >> STAKEHOLDERS:
#    - HR business partners
#    - People analytics team
#    - Department managers
#    - Executive leadership
#
# >> BUSINESS SUCCESS CRITERIA:
#    - Produce a ranked attrition-risk view that HR can use for intervention planning.
#    - Reach recall of at least 0.60 on attrition cases so a majority of leavers are flagged.
#    - Maintain precision near or above 0.40 to avoid overwhelming HR with false positives.
#    - Surface actionable drivers such as overtime, travel burden, tenure, and job satisfaction.
#
# >> EXPECTED BENEFITS:
#    - Lower replacement and onboarding costs
#    - Better workforce planning
#    - More targeted retention programmes
#    - Improved employee experience for at-risk groups

# %% [markdown]
# ---
# ### Task 2: Assess Situation
#
# This task involves a more detailed fact-finding about all of the resources, constraints, assumptions, and other factors that should be considered in determining the data analysis goal and project plan. Key areas to assess:
#
# - **Resources Inventory:** Personnel, data sources, computing resources, and software available.
# - **Requirements, Assumptions, and Constraints:** Project schedule, legal/ethical considerations, data access limitations, and budget.
# - **Risks and Contingencies:** Identify potential risks (e.g., data unavailability, quality issues, privacy concerns) and how to mitigate them.
# - **Terminology Glossary:** Define key domain-specific terms relevant to the project.
# - **Costs and Benefits:** A cost-benefit analysis of the project.
#
# **Instructions:** Document your situation assessment as a structured dictionary or set of variables.

# %%
situation_assessment = {
    "resources": {
        "data_assets": [
            "IBM HR attrition dataset in CSV format",
            "Employee demographic, compensation, travel, satisfaction, and tenure fields",
        ],
        "tooling": ["Python", "Jupyter Notebook", "pandas", "scikit-learn", "matplotlib", "seaborn"],
        "personnel": ["Data analyst", "HR domain stakeholder", "Project reviewer"],
    },
    "requirements": {
        "business": [
            "Prioritise retention interventions using interpretable drivers",
            "Keep the workflow reproducible and easy to review",
        ],
        "technical": [
            "Binary classification workflow with reproducible train/test split",
            "Documented data preparation and evaluation criteria",
        ],
    },
    "assumptions": [
        "The dataset is representative of typical employee attrition patterns.",
        "Attrition is a business-relevant proxy for regrettable employee loss.",
        "The available features are observed before the attrition outcome occurs.",
    ],
    "constraints": [
        "Single static dataset with no event timestamps",
        "No direct intervention or cost labels for ROI modelling",
        "Class imbalance because attrition cases are a minority class",
    ],
    "risks": [
        "The dataset may not fully reflect current workforce conditions.",
        "Some strong predictors may be correlational rather than causal.",
        "Operational use requires governance to avoid unfair treatment of employees.",
    ],
}

# %%
# Display situation assessment
import json
print(json.dumps(situation_assessment, indent=2))
# Out:
# {
#   "resources": {
#     "data_assets": [
#       "IBM HR attrition dataset in CSV format",
#       "Employee demographic, compensation, travel, satisfaction, and tenure fields"
#     ],
#     "tooling": [
#       "Python",
#       "Jupyter Notebook",
#       "pandas",
#       "scikit-learn",
#       "matplotlib",
#       "seaborn"
#     ],
#     "personnel": [
#       "Data analyst",
#       "HR domain stakeholder",
#       "Project reviewer"
#     ]
#   },
#   "requirements": {
#     "business": [
#       "Prioritise retention interventions using interpretable drivers",
#       "Keep the workflow reproducible and easy to review"
#     ],
#     "technical": [
#       "Binary classification workflow with reproducible train/test split",
#       "Documented data preparation and evaluation criteria"
#     ]
#   },
#   "assumptions": [
#     "The dataset is representative of typical employee attrition patterns.",
#     "Attrition is a business-relevant proxy for regrettable employee loss.",
#     "The available features are observed before the attrition outcome occurs."
#   ],
#   "constraints": [
#     "Single static dataset with no event timestamps",
#     "No direct intervention or cost labels for ROI modelling",
#     "Class imbalance because attrition cases are a minority class"
#   ],
#   "risks": [
#     "The dataset may not fully reflect current workforce conditions.",
#     "Some strong predictors may be correlational rather than causal.",
#     "Operational use requires governance to avoid unfair treatment of employees."
#   ]
# }

# %%
phase_1_notes = [
    "This project is framed as a retention-prioritisation problem, not an automated employment decision system.",
    "Interpretability matters because HR teams need to explain why employees are flagged as high risk.",
    "Class imbalance should be handled explicitly during modelling and evaluation.",
]

for note in phase_1_notes:
    print(f"- {note}")
# Out:
# - This project is framed as a retention-prioritisation problem, not an automated employment decision system.
# - Interpretability matters because HR teams need to explain why employees are flagged as high risk.
# - Class imbalance should be handled explicitly during modelling and evaluation.

# %% [markdown]
# ---
# ### Task 3: Determine Data Mining Goals
#
# A business goal states objectives in business terminology. A data mining goal states project objectives in technical terms. This task converts the business objectives identified in Task 1 into specific, measurable data mining goals:
#
# - **Data Mining Problem Type:** Classify the problem (e.g., classification, regression, clustering, anomaly detection, association rule mining, etc.).
# - **Data Mining Goals:** State the technical objectives clearly (e.g., "Build a classification model to predict [target variable] with an F1-score ≥ 0.85").
# - **Data Mining Success Criteria:** Define the technical metrics that will be used to evaluate the model's performance (e.g., accuracy, precision, recall, RMSE, silhouette score).
#
# **Instructions:** Map your business objectives to concrete data mining goals.

# %%
data_mining_goals = {
    "problem_type": "Binary Classification",
    "target_variable": "Attrition",
    "unit_of_analysis": "One employee record",
    "candidate_features": [
        "OverTime",
        "BusinessTravel",
        "MonthlyIncome",
        "JobRole",
        "Department",
        "DistanceFromHome",
        "YearsAtCompany",
        "YearsInCurrentRole",
        "WorkLifeBalance",
        "JobSatisfaction",
        "EnvironmentSatisfaction",
    ],
    "technical_success_metrics": {
        "primary_metric": "F1-score for attrition class",
        "secondary_metrics": ["Recall", "Precision", "ROC-AUC", "Accuracy"],
    },
    "modelling_requirements": [
        "Use stratified evaluation because the target is imbalanced.",
        "Compare at least one interpretable model and one non-linear ensemble.",
        "Persist the best model and a metrics summary for later phases.",
    ],
}

# %%
# Display the mapping from business objectives to data mining goals
print("=" * 60)
print("BUSINESS TO DATA MINING GOAL MAPPING")
print("=" * 60)
print(f"\nBusiness Objective : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"\nTechnical Goals:")
for goal in data_mining_goals['modelling_requirements']:
    print(f"  - {goal}")
print(f"\nSuccess Metrics:")
metrics = data_mining_goals['technical_success_metrics']
print(f"  - Primary: {metrics['primary_metric']}")
for metric in metrics['secondary_metrics']:
    print(f"  - Secondary: {metric}")
# Out:
# ============================================================
# BUSINESS TO DATA MINING GOAL MAPPING
# ============================================================
#
# Business Objective : Predict whether an employee is likely to leave the company and identify the strongest drivers of attrition.
# Problem Type       : Binary Classification
# Target Variable    : Attrition
#
# Technical Goals:
#   - Use stratified evaluation because the target is imbalanced.
#   - Compare at least one interpretable model and one non-linear ensemble.
#   - Persist the best model and a metrics summary for later phases.
#
# Success Metrics:
#   - Primary: F1-score for attrition class
#   - Secondary: Recall
#   - Secondary: Precision
#   - Secondary: ROC-AUC
#   - Secondary: Accuracy

# %% [markdown]
# ---
# ### Task 4: Produce Project Plan
#
# Describe the intended plan for achieving the data mining goals and thereby achieving the business goals. The plan should specify:
#
# - **Tools and Techniques:** The data mining tools (libraries, frameworks) and modelling techniques you plan to use.
# - **Project Plan / Timeline:** A step-by-step plan with estimated durations for each remaining CRISP-DM phase.
# - **Dependencies:** Any dependencies between tasks or on external factors.
# - **Initial Assessment of Tools and Techniques:** A brief justification for why the chosen tools and techniques are appropriate.
#
# **Instructions:** Outline your full project plan as a structured data object below.

# %%
project_plan = {
    "tools": ["Jupyter Notebook", "pandas", "NumPy", "scikit-learn", "matplotlib", "seaborn", "joblib"],
    "techniques": [
        "Exploratory data analysis",
        "Feature selection and feature engineering",
        "Categorical encoding",
        "Binary classification",
        "Cross-validation",
        "Model comparison and threshold-aware evaluation",
    ],
    "deliverables": [
        "Completed CRISP-DM phase notebooks",
        "Prepared modelling dataset",
        "Model comparison results",
        "Business-facing deployment and monitoring recommendations",
    ],
    "milestones": [
        "Phase 1: define business and analytical success criteria",
        "Phase 2: profile the dataset and document quality issues",
        "Phase 3: prepare a model-ready dataset",
        "Phase 4: train and compare candidate models",
        "Phase 5: evaluate business readiness",
        "Phase 6: document deployment and maintenance plan",
    ],
    "dependencies": [
        "Availability of the HR attrition dataset",
        "Notebook environment with data-science libraries installed",
        "Stakeholder agreement on acceptable recall vs. precision trade-off",
    ],
}

# %%
# Display the project plan
print("=" * 60)
print("PROJECT PLAN")
print("=" * 60)

print("\nTools:", ", ".join(project_plan['tools']) if project_plan['tools'] else "[Not yet defined]")
print("Techniques:", ", ".join(project_plan['techniques']) if project_plan['techniques'] else "[Not yet defined]")

print("\nMilestones:")
for milestone in project_plan['milestones']:
    print(f"  - {milestone}")

print("\nDependencies:")
for dep in project_plan['dependencies']:
    print(f"  - {dep}")

print("\nDeliverables:")
for item in project_plan['deliverables']:
    print(f"  - {item}")
# Out:
# ============================================================
# PROJECT PLAN
# ============================================================
#
# Tools: Jupyter Notebook, pandas, NumPy, scikit-learn, matplotlib, seaborn, joblib
# Techniques: Exploratory data analysis, Feature selection and feature engineering, Categorical encoding, Binary classification, Cross-validation, Model comparison and threshold-aware evaluation
#
# Milestones:
#   - Phase 1: define business and analytical success criteria
#   - Phase 2: profile the dataset and document quality issues
#   - Phase 3: prepare a model-ready dataset
#   - Phase 4: train and compare candidate models
#   - Phase 5: evaluate business readiness
#   - Phase 6: document deployment and maintenance plan
#
# Dependencies:
#   - Availability of the HR attrition dataset
#   - Notebook environment with data-science libraries installed
#   - Stakeholder agreement on acceptable recall vs. precision trade-off
#
# Deliverables:
#   - Completed CRISP-DM phase notebooks
#   - Prepared modelling dataset
#   - Model comparison results
#   - Business-facing deployment and monitoring recommendations

# %%
# Optional: Summarise all Phase 1 outputs for reference in subsequent phases
print("=" * 60)
print("PHASE 1 SUMMARY: BUSINESS UNDERSTANDING")
print("=" * 60)
print(f"\nPrimary Objective  : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"Tools Planned      : {', '.join(project_plan['tools']) if project_plan['tools'] else 'TBD'}")
print(f"Techniques Planned : {', '.join(project_plan['techniques']) if project_plan['techniques'] else 'TBD'}")
# Out:
# ============================================================
# PHASE 1 SUMMARY: BUSINESS UNDERSTANDING
# ============================================================
#
# Primary Objective  : Predict whether an employee is likely to leave the company and identify the strongest drivers of attrition.
# Problem Type       : Binary Classification
# Target Variable    : Attrition
# Tools Planned      : Jupyter Notebook, pandas, NumPy, scikit-learn, matplotlib, seaborn, joblib
# Techniques Planned : Exploratory data analysis, Feature selection and feature engineering, Categorical encoding, Binary classification, Cross-validation, Model comparison and threshold-aware evaluation
